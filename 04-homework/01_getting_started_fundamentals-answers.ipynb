# %% [markdown]
# # Getting Started: Python Fundamentals
# ## Practice Problems

# %% [markdown]
# ###1. What types are involved in the following expressions? What data type will each expression evaluate to?
#
# `8 * 2.5`

# %%
print(type(8))
print(type(2.5))
print(type(8 * 2.5))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'float'>

# %% [markdown]
# `9 / 2`

# %%
print(type(9))
print(type(2))
print(type(9 / 2))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# `9 // -2`

# %%
print(type(9))
print(type(-2))
print(type(9 // -2))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %% [markdown]
# `1.5 * 2 >= 7 - 3`

# %%
print(type(1.5))
print(type(2))
print(type(7))
print(type(3))
print(type(1.5 * 2 >= 7 - 3))
# Out:
# <class 'float'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'bool'>

# %% [markdown]
# ###3. In which order will the expressions be evaluated.
#
# `6 * 3 + 7 * 4`
#
# Answer: `*` > `*` > `+`
#
# `5 - 2 * 3 ** 4`
#
# Answer: `**` > `*` > `-`
#
# `(5 - 2) * 3 ** 4`
#
# Answer: `(-)` > `**` > `*`
#
# `5 + 2 >= 3 * 4`
#
# Answer: `*` > `+` > `>=`

# %% [markdown]
# ###2. Which of these expressions results in an error? Why does each error occur?

# %%
((((5 * 4 ** 7))))
# Out:
# 81920

# %% [markdown]
# Answer: Valid -- Python accepts extraneous parentheses.

# %%
84 *= 0.5 / 7
# Out:
#   File "<ipython-input-38-48e20a39a625>", line 1
#     84 *= 0.5 / 7
#                  ^
# SyntaxError: can't assign to literal

# %% [markdown]
# Answer: Error -- Python thinks we are trying to assign a value to 84, which is an integer literal. We can't change its value!

# %%
(-(-(-(-5 * (4 + 3)))))
# Out:
# 35

# %% [markdown]
# Answer: Valid -- The `-` negates the value in the parentheses.

# %%
5 * 3 = weight
# Out:
#   File "<ipython-input-40-15f378ab3f58>", line 1
#     5 * 3 = weight
#                   ^
# SyntaxError: can't assign to operator

# %% [markdown]
# Answer: Error -- We cannot assign a value to an expression, even if `weight` had been defined.

# %%
73 / -----------5
# Out:
# -14.6

# %% [markdown]
# *Answer*: Valid -- negatives cancel each other out.

# %% [markdown]
# ### 3. Following the function design recipe, define:
#   * a function that converts Fahrenheit into Celsius
#   * a function that converts kilometers into miles. (Assume there are 1.6 kilometers in a mile.)

# %%
def F2C(F):
  C = (5/9)(F - 32)
  return C

def km2miles(km):
  miles = km/1.6
  return miles

# %% [markdown]
# ### 4. What value is printed in the below code?

# %%
answer = 3

def answer_to_everything():
    '''Return the answer to life, the universe, and everything'''
    answer = 42
    return answer
    
answer_to_everything()

print(answer)
# Out:
# 3

# %% [markdown]
# Answer: 3. The answer variable in our function is locally scoped -- our program cannot access the value 42 from outside of the function, including when we called print(answer).
#
# Although we called answer_to_everything(), we did not assign the output to a variable.

# %% [markdown]
# ### 5. Complete the examples in the docstring below, then write the body of the function. You can assume `num` is always >= 0.

# %%
def repeat(string, num):
    ''' Return string repeated num times.
    >>> repeat('yes', 4)
    'yesyesyesyes'
    >>> repeat('no', 0)
    # your expected output here
    >>> repeat('yesnomaybe', 3)
    # your expected output here
    '''
    output = string*num
    return output

# %% [markdown]
# ### 6. Complete the function below. You can assume that `number` will always be a string with 10 digits and that the first 3 digits will always be the area code.

# %%
from pickle import TRUE
def is_416_number(number):
    ''' Check whether the number has a 416 area code.
    >>> is_416_number('(416)-555-5555')
    True
    >>> is_416_number('514 416 5555')
    False
    >>> is_416_number('4165554160')
    True
    '''
    # replace parens w/ nothing
    number = number.replace('(', '')
    number = number.replace(')', '')
    output = number[:3] == '416'
    return output
