# %%
5 + 6
# Out:
# 11

# %% [markdown]
#    - Utilize keyboard shortcuts for faster execution:
#      - `Shift + Enter`: Run the current cell and move to the next cell.
#      - `Ctrl + Enter`: Run the current cell and stay on the same cell.
#      - `Alt + Enter`: Run the current cell and insert a new cell below.

# %%
2 + 2
# Out:
# 4

# %%
3 + 3
# Out:
# 6

# %%
4 + 4
# Out:
# 8

# %%
print("hello!")
# Out:
# hello!

# %%
print("goodbye!")
# Out:
# goodbye!

# %%
5 + 6 # int -> whole numbers
# Out:
# 11

# %%
11.0 + 12.1 # float -> decimal number
# Out:
# 23.1

# %%
5 + 5
# Out:
# 10

# %%
10 / 3
# Out:
# 3.3333333333333335

# %%
# integer division 
# divide first operand by second & return quotient rounded down to nearest integer

10 // 3
# Out:
# 3

# %%
# modulo operator
# return the remainder of the division of the first operand by the second

10 % 3
# Out:
# 1

# %%
# exponentiation
# raising a number to a power

10 ** 3
# Out:
# 1000

# %%
# bool
# True or False

# %%
50 > 25
# Out:
# True

# %%
-15 >= -14.99
# Out:
# False

# %%
20 == 20
# Out:
# True

# %%
20 != 20
# Out:
# False

# %% [markdown]
# ## Operator precedence
#
# Arithmetic and comparison operators are evaluated in the following order. We can enclose operations in parentheses to override the order of precedence -- operations in parentheses are evaluated before the rest of the expression.
#
# | Order | Operator | Description |
# |---|---|---|
# | 1 | `**` | Exponentiation |
# | 2 | `-`| Negation |
# | 3 | `*`, `/`, `//`, `%` | Multiplication, division, integer division, and modulo |
# | 4 | `+`, `-` | Addition and subtraction |
# | 5 | `<`, `<=`, `>`, `>=`, `==`, `!=` | Less than, less than or equal to, greater than, greater than or equal to, equal, not equal |

# %%
# negation: unary operation that changes the sign of a number
# subtraction: binary operation, subtract one value from another

# %%
4 - 3
# Out:
# 1

# %%
-5
# Out:
# -5

# %%
# variable names

# letters, digits, and underscore
# cannot start with a digit
# case sensitive

# %%
degrees_celsius = 25

# %%
degrees_celsius
# Out:
# 25

# %%
degrees_fahrenheit = (9 / 5) * degrees_celsius + 32

# %%
degrees_fahrenheit
# Out:
# 77.0

# %%
(9 / 5) * 25 + 32
# Out:
# 77.0

# %%
degrees_celsius = 0

# %%
degrees_celsius
# Out:
# 0

# %%
degrees_fahrenheit
# Out:
# 77.0

# %%
kaylie_cups = 5

# %%
total_cups = kaylie_cups + 10

# %%
kaylie_cups
# Out:
# 5

# %%
total_cups
# Out:
# 15

# %%
kaylie_cups = 0

# %%
kaylie_cups
# Out:
# 0

# %%
total_cups
# Out:
# 15

# %%
total_cups = kaylie_cups + 10

# %%
total_cups
# Out:
# 10

# %%
# we can reassign a variable, and that will change the value which that variable refers to

# BUT reassigning a varibale does not change any other variable

# %%
degrees_celsius
# Out:
# 0

# %%
degrees_celsius = degrees_celsius + 10 # 0 + 10 = 10

# %%
degrees_celsius
# Out:
# 10

# %%
a = 1

# %%
a
# Out:
# 1

# %%
b = a

# %%
b
# Out:
# 1

# %%
a = 2

# %%
a
# Out:
# 2

# %%
b
# Out:
# 1

# %%
no_of_weeks = 4

# %%
no_of_weeks = no_of_weeks + 10 # 4 + 10 = 14

# %%
no_of_weeks
# Out:
# 14

# %%
no_of_weeks += 10 # 14 + 10 = 24

# %%
no_of_weeks

# line 104 does the same thing as 106, just in a more concise way - augmented assignment
# Out:
# 24

# %%
degrees_celsius = 0
degrees_celsius
# Out:
# 0

# %%
degrees_celsius -= 10
degrees_celsius
# Out:
# -10

# %%
12 = x
# Out:
#   Cell In[110], line 1
#     12 = x
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
12 -
# Out:
#   Cell In[111], line 1
#     12 -
#          ^
# SyntaxError: invalid syntax

# %%
my_variable + 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 my_variable + 1
#
# NameError: name 'my_variable' is not defined

# %%
# This is a comment

# %%
# white space:
# a space on either side of an operand
# split code across multiple lines by wrapping it in parentheses

# %%
4 + 1
# Out:
# 5

# %%
(100000000 + 
 500000000)
# Out:
# 600000000

# %%
# comments:
# explain your code and plan future work in plain language
# toggle lines of code on/off during debugging

# %%
kaylie_vacations = 30
kaylie_vacations = kaylie_vacations + 10
kaylie_vacations = kaylie_vacations - 1

# %%
kaylie_vacations
# Out:
# 39

# %%
# clear and consistent variable names
# descriptive
# consistent naming

dog1 = 'Penny'
dog_2 = 'Boone'
dog_three = 'Bailey'

# %% [markdown]
# Version 1
# ```python
# studentone_grade=90
# StudentGrade2=50
# stu3gr=74
# avggrade=(studentone_grade+StudentGrade2+stut3gr)/3
# ```
#
# Version 2
# ```python
# student1_grade = 90
# student2_grade = 50
# student3_grade = 74
# average_grade = ((student1_grade
#                   + student2_grade
#                   + student3_grade)
#                  / 3)
# ```

# %%
# function is a named block of code that performs a specific task
# take zero or more input values and produce one or more return values

# %%
print(42)
# Out:
# 42

# %%
42
# Out:
# 42

# %%
type(42)
# Out:
# int

# %%
abs(-43)
# Out:
# 43

# %%
int(3.99)
# Out:
# 3

# %%
float(7)
# Out:
# 7.0

# %%
round(2/3)
# Out:
# 1

# %%
2/3
# Out:
# 0.6666666666666666

# %%
help(round)
# Out:
# Help on built-in function round in module builtins:
#
# round(number, ndigits=None)
#     Round a number to a given precision in decimal digits.
#
#     The return value is an integer if ndigits is omitted or None.  Otherwise
#     the return value has the same type as the number.  ndigits may be negative.

# %%
round(2/3, 4)
# Out:
# 0.6667

# %%
print(round(abs(-16) * 1.5))
# Out:
# 24

# %%
abs(-16)
# Out:
# 16

# %%
round(16 * 1.5)
# Out:
# 24

# %%
print(24)
# Out:
# 24

# %%
def c_to_f(degrees_c):
    degrees_f = (9 / 5) * degrees_c + 32
    return degrees_f

# %%
degrees_c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[142], line 1
# ----> 1 degrees_c
#
# NameError: name 'degrees_c' is not defined

# %%
c_to_f(100)
# Out:
# 212.0

# %%
# parameters
# placeholders for the values that will be provided when the function is called
# local variables within the function, only accessible inside function's code block

# argument
# actual value that is passed to the function when it is called
# correspond to the parameters in the function definition and provide the data for the 
# function to work on

# %%
c_to_f(-11)
# Out:
# 12.2

# %%
c_to_f(0)
# Out:
# 32.0

# %%
weather_today = 100

# %%
weather_today
# Out:
# 100

# %%
degrees_c = 1000

# %%
degrees_c
# Out:
# 1000

# %%
def divide(dividend, divisor):
    output = dividend / divisor
    return output

# %%
divide(100, 5)
# Out:
# 20.0

# %%
divide(100, 0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 divide(100, 0)
#
# Cell In[149], line 2, in divide(dividend, divisor)
#       1 def divide(dividend, divisor):
# ----> 2     output = dividend / divisor
#       3     return output
#
# ZeroDivisionError: division by zero

# %%
def calc_sales_tax(price, tax_rate=0.13):
    tax_amt = price * tax_rate
    return tax_amt

# %%
calc_sales_tax(15)
# Out:
# 1.9500000000000002

# %%
15 * 0.13
# Out:
# 1.9500000000000002

# %%
calc_sales_tax(5, 0.08)
# Out:
# 0.4

# %%
5 * 0.08
# Out:
# 0.4

# %%
def calc_total_bill(price, tax_rate=0.13, tip_rate=0.15):
    tax_amt = price * tax_rate
    tip_amt = price * tip_rate
    return price + tax_amt + tip_amt

# %%
calc_total_bill(100)
# Out:
# 128.0

# %%
100 * 0.13 + 100 * 0.15 + 100
# Out:
# 128.0

# %%
calc_total_bill(100, 0.18) # wanted to tip 18%
# Out:
# 133.0

# %%
100 + 100 * 0.18 + 100 * 0.15
# Out:
# 133.0

# %%
calc_total_bill(100, tip_rate=0.18)
# Out:
# 131.0

# %%
100 + 100 * 0.13 + 100 * 0.18
# Out:
# 131.0

# %%
help(round)
# Out:
# Help on built-in function round in module builtins:
#
# round(number, ndigits=None)
#     Round a number to a given precision in decimal digits.
#
#     The return value is an integer if ndigits is omitted or None.  Otherwise
#     the return value has the same type as the number.  ndigits may be negative.

# %%
help(c_to_f)
# Out:
# Help on function c_to_f in module __main__:
#
# c_to_f(degrees_c)

# %%
def c_to_f(degrees_c):
    """Convert degrees from Celsius to Fahrenheit"""
    return ((9 / 5) * degrees_c + 32)

# %%
help(c_to_f)
# Out:
# Help on function c_to_f in module __main__:
#
# c_to_f(degrees_c)
#     Convert degrees from Celsius to Fahrenheit
