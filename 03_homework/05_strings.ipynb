# %% [markdown]
# # Strings
# ## Practice Problems

# %% [markdown]
# ### 1. Write a multi-line string about anything you want and print it

# %%
# Your code goes here
# Write a multi-line string about anything you want and print it
my_string = """
Hello World!
I am a multi-line string!
ad"""
print(my_string)
# Out:
# Hello World!
# I am a multi-line string!
# ad

# %% [markdown]
# ### 2. Append a "world" to the following word.

# %%
# Your code goes here
my_string = "WORLD" + my_string
print(my_string)
# Out:
# WORLDWORLD
# Hello World!
# I am a multi-line string!
# ad
