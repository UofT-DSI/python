# %% [markdown]
# # Inputs
# ## Practice Problems

# %% [markdown]
# ### 1. Use the modules discussed in class to complete the following tasks.
#
#
#
# 1.   Import the `math` module and use it to write a function that takes the radius and then outputs the area of a circle.
# 2.   Import the `datetime` module and create a date object for your birthdate. Convert this to a readable string.
# 3.   Import the `re` module and use the `search` function to see if the string "The weather in Toronto is abnormally warm", starts with "The" and ends with "warm".

# %%
# Your code goes here

# %% [markdown]
# <details>
#   <summary>Answer</summary>
#
#   ```python
#   import math
#
#   def circle_area(radius):
#     return math.pi*radius**2
#   ```
# </details>

# %%
# Your code goes here
# Out:
# 'Friday 11 December 1992'

# %% [markdown]
# <details>
#   <summary>Answer</summary>
#
#   ```python
#   import datetime
#
#   birthday = datetime.datetime(1992,12,11)
#   birthday.strftime('%A %d %B %Y')
#   ```
# </details>

# %%
# Your code goes here
# Out:
# <re.Match object; span=(0, 41), match='The weather in Toronto is abnormally warm'>

# %% [markdown]
# <details>
#   <summary>Answer</summary>
#
#   ```python
#   import re
#
#   txt = "The weather in Toronto is abnormally warm"
#   re.search("^The.*warm$", txt)
#   ```
# </details>

# %% [markdown]
# ### 2. Using `w`, create a file called `fruits.txt` and write the string "tangerines" to it. Next, use `a` to append the string "dragon fruit" to the file on a new line. Finally, use `r` to read and print the entire file.

# %%
# Your code goes here
# Out:
# tangerines
# dragon fruit

# %% [markdown]
# <details>
#   <summary>Answer</summary>
#
#   ```python
#   with open('fruits.txt', 'w') as fruit_file:
#     fruit_file.write('tangerines')
#
#   with open('fruits.txt', 'a') as fruit_file:
#     fruit_file.write('\ndragon fruit')
#
#   with open('fruits.txt', 'r') as fruit_file:
#     print(fruit_file.read())
#   ```
# </details>
