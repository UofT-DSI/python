# %% [markdown]
# # Assignment #3
#
# ### Research and discuss a recent example of algorithmic biases. This should be approximately 1 page and you should make sure to use at lease 3 primary and/or secondary resources. (10 marks)
