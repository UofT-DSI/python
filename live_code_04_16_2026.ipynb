# %%
vowels = ['a', 'e', 'i', 'o', 'u']

# %%
scores = [90, 80, 82, 76, 81]

# %%
grades = ['K', 1, 2,3,4,5,6,7]

# %%
foods = [
    ['apple', 'banana', 'orange'],
    ['carrot', 'spinach', 'kale']
]

# %%
fruits = ['apple', 'banana', 'orange']

# %%
fruits[0]
# Out:
# 'apple'

# %%
fruits[0:2]
# Out:
# ['apple', 'banana']

# %%
vowels
# Out:
# ['a', 'e', 'i', 'o', 'u']

# %%
'e' in vowels
# Out:
# True

# %%
'f' in vowels
# Out:
# False

# %%
len(vowels)
# Out:
# 5

# %%
2 * vowels
# Out:
# ['a', 'e', 'i', 'o', 'u', 'a', 'e', 'i', 'o', 'u']

# %%
vowels + fruits
# Out:
# ['a', 'e', 'i', 'o', 'u', 'apple', 'banana', 'orange']

# %%
#change the value in a list

fruits[1] = "kiwi"

# %%
fruits
# Out:
# ['apple', 'kiwi', 'orange']

# %%
rainbow = ['red', 'orange', 'yellow', 'green', 'blue', 'violet']

# %%
rainbow
# Out:
# ['red', 'orange', 'yellow', 'green', 'blue', 'violet']

# %%
rainbow.append('purple')

# %%
rainbow.extend(['magenta', 'pink', 'purple'])

# %%
rainbow
# Out:
# ['red',
#  'orange',
#  'yellow',
#  'green',
#  'blue',
#  'violet',
#  'purple',
#  'magenta',
#  'pink',
#  'purple']

# %%
del rainbow [0:3]

# %%
rainbow
# Out:
# ['green', 'blue', 'violet', 'purple', 'magenta', 'pink', 'purple']

# %%
rainbow.sort()

# %%
rainbow
# Out:
# ['blue', 'green', 'magenta', 'pink', 'purple', 'purple', 'violet']

# %%
scores
# Out:
# [90, 80, 82, 76, 81]

# %%
scores.sort()

# %%
scores
# Out:
# [76, 80, 81, 82, 90]

# %%
sorted_scores = sorted(scores, reverse =False)

# %%
sorted_scores
# Out:
# [76, 80, 81, 82, 90]

# %%
scores
# Out:
# [76, 80, 81, 82, 90]

# %%
sorted_scores
# Out:
# [76, 80, 81, 82, 90]

# %%
nums = [10, 20, 30, 40, 50]

# %%
nums[1:4]
# Out:
# [20, 30, 40]

# %%
nums[:3]
# Out:
# [10, 20, 30]

# %%
coordinates = {47.6, -38.2}

# %%
empty_tuple = {}

# %%
sorted(coordinates)
# Out:
# [-38.2, 47.6]

# %%
nums = {10, 20, 30, 40, 50}

# %%
nums [0] = 300
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_48075/2163289943.py in <cell line: 0>()
# ----> 1 nums [0] = 300
#
# TypeError: 'set' object does not support item assignment

# %%
unique_numbers = {1, 2, 3, 3, 3}  # sets only return unique values.

# %%
unique_numbers # see unique values only
# Out:
# {1, 2, 3}

# %%
postal_codes = {'M5B', "M91", "L4S", "M5B"}

# %%
set(postal_codes)
# Out:
# {'L4S', 'M5B', 'M91'}

# %%
empty_set = set()

# %%
#dictionary of capitals

capitals = {
      "Canada": "Ottawa", "United States": "Washington DC"
}

# %%
capitals["Canada"]
# Out:
# 'Ottawa'

# %%
capitals["France"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_48075/1373879215.py in <cell line: 0>()
# ----> 1 capitals["France"]
#
# KeyError: 'France'

# %%
capitals.get("Canada", "Not found")
# Out:
# 'Ottawa'

# %%
"Canada" in capitals
# Out:
# True

# %%
capitals["Italy"] = "Milan"

# %%
capitals
# Out:
# {'Canada': 'Ottawa', 'United States': 'Washington DC', 'Italy': 'Milan'}

# %%
capitals["Italy"] = "Rome"

# %%
capitals
# Out:
# {'Canada': 'Ottawa', 'United States': 'Washington DC', 'Italy': 'Rome'}

# %%
del capitals["Italy"]

# %%
capitals
# Out:
# {'Canada': 'Ottawa', 'United States': 'Washington DC'}

# %%
capitals.keys
# Out:
# <function dict.keys>

# %%
if 'Ottawa' in capitals.values():
  print ("Ottawa is a capital")
else:
    print ("Ottawa is not a capital")
# Out:
# Ottawa is a capital

# %%
students = {
    "name": "Alice",
    "age": 20,
    "major": "Physics"
}

# %%
students ["major"]
# Out:
# 'Physics'

# %%
students = {
    "name": "Alice",
    "age": 20
}

students ["age"] = 21

# %%
students
# Out:
# {'name': 'Alice', 'age': 21}

# %%
students.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
students.get("Gender", "Not Found")
# Out:
# 'Not Found'

# %%
students["grade"] = "A"

# %%
students
# Out:
# {'name': 'Alice', 'age': 21, 'grade': 'A'}

# %%
students.get("name")
# Out:
# 'Alice'

# %%
vowel = ['a', 'e', 'i', 'o', 'u']
for vowel in vowels:
  print (vowel)
# Out:
# u

# %%
vowels
# Out:
# 'u'

# %%
vowel
# Out:
# 'u'

# %%
for i in range(5):
  print (i, i*2)
# Out:
# 0 0
# 1 2
# 2 4
# 3 6
# 4 8

# %%
input_files = ['data_01.csv', 'data02.csv', 'data03.csv', 'data04.csv']

output_files = [] #empty list

# %%
for i in input_files:

  output_file_name = "processed_" + i.replace('.csv', '.xlsx')

  output_files.append(output_file_name)

# %%
output_files
# Out:
# ['processed_data_01.xlsx',
#  'processed_data02.xlsx',
#  'processed_data03.xlsx',
#  'processed_data04.xlsx']

# %%
for i in range(3):
    print (i)
# Out:
# 0
# 1
# 2

# %%
stops = ['Sheppard Yonge', 'Dundas', 'Bay', 'Bathurst']

for idx, stop in enumerate(stops): # enumerate gives us two values. it gives us the index and the value of the item as well
    print (f'Stop {idx + 1}, is {stop}.')
# Out:
# Stop 1, is Sheppard Yonge.
# Stop 2, is Dundas.
# Stop 3, is Bay.
# Stop 4, is Bathurst.

# %%
prices = {
    "apple": 2,
    "banana": 1,
    "orange": 3
}

# %%
for fruit, price in prices.items():
  print (fruit, price)
# Out:
# apple 2
# banana 1
# orange 3

# %%
for fruit, price in prices.items():
  print(f"{fruit} costs: ${price}")
# Out:
# apple costs: $2
# banana costs: $1
# orange costs: $3

# %%
for i in range (1,3):
  for j in range (1,10):
    print(f"{i} * {j} = {i*j}")
# Out:
# 1 * 1 = 1
# 1 * 2 = 2
# 1 * 3 = 3
# 1 * 4 = 4
# 1 * 5 = 5
# 1 * 6 = 6
# 1 * 7 = 7
# 1 * 8 = 8
# 1 * 9 = 9
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18

# %%
countdown = 4
while countdown > 0:
  print (countdown)
  if countdown == 3:
    break
  countdown -=1
# Out:
# 4
# 3
