# %%
word = "supercalifragilisticexpialdocious"
word[0:6]
# Out:
# 'superc'

# %%
number = "(647)-225-7154"
number[1:4]
# Out:
# '647'

# %%
"I am not yelling".upper()
# Out:
# 'I AM NOT YELLING'

# %%
"I am not yelling".lower()
# Out:
# 'i am not yelling'

# %%
"THis string is unusual".count("e")
# Out:
# 0

# %%
"This string is unusual".count("s")
# Out:
# 4

# %%
"file_name.csv".endswith(".csv")
# Out:
# True

# %%
"file name".replace(" ", "_")
# Out:
# 'file_name'

# %%
first_name = "Taqi"
last_name = "Premjee"

"Initials are: {}. {}".format(first_name[0], last_name[0])
# Out:
# 'Initials are: T. P'

# %%
first_name = "Taqi"
last_name = "Premjee"

f"Initials are: {first_name[0]}.{last_name[0]}" #this one has to start with an f since it is an f string.
# Out:
# 'Initials are: T.P'

# %%
int ('17')
# Out:
# 17

# %%
float ('17')
# Out:
# 17.0

# %%
str (37.5)
# Out:
# '37.5'

# %%
"the year is " + str(2026)
# Out:
# 'the year is 2026'

# %%
age = input("How old are you?")

# %%
age #this will return it as a string
# Out:
# '27'

# %%
int(age) #you need to add int function if you want to do any match with it
# Out:
# 27

# %%
def greet_user():
    name = input ("Enter your name")
    return (f"Hello,{name}!")

# %%
greet_user()
# Out:
# 'Hello, Taqi!'

# %%
## EXERCISE

# %%
color = input ("what is your favorite color?")

print (color)
# Out:
# Pink

# %%
firstName = input ("What is your first name?")
lastName = input ("what is your last name?")

print (firstName + " " + lastName)
# Out:
# John Smith

# %%
year = 2022

if year >= 2000:
    print ("We are in the 21st century")
# Out:
# We are in the 21st century

# %%
year = 2000

if year >= 2001:
    print("we are in the 21st century")
else:
    print ("we are not in the 21st century")
# Out:
# we are not in the 21st century

# %%
year = 1867

if year >= 2000:
    print ("we are in the 21st century")
elif year >= 1900:
    print ("we are in the 20th century")
else:
    print ("we are not in the 20th or 21st century")
# Out:
# we are not in the 20th or 21st century

# %%
temperature = 47
if temperature < 0:
    print ("it is freezing cold!!! brrrr")
elif temperature >=1 and temperature <=15:
    print ("it is cold!")
elif temperature >=16 and temperature <=30:
    print ("it is hot!")
elif temperature >=31 and temperature <=45:
    print ("it is really hot!!!")
else:
    print("it is boiling!!")
# Out:
# it is boiling!!

# %%
temperature = int (input("what is the temperature?"))

if temperature < 0:
    print ("it is freezing cold!!! brrrr")
elif temperature >=1 and temperature <=15:
    print ("it is cold!")
elif temperature >=16 and temperature <=30:
    print ("it is hot!")
elif temperature >=31 and temperature <=45:
    print ("it is really hot!!!")
else:
    print("it is boiling!!")
# Out:
# it is boiling!!

# %%
def weather_commentary():
    temperature = float(input ("what is the temperature in celsius?"))

    if temperature <= 0:
        print ("it is freezing cold")
    elif temperature <= 15:
        print ("it is cold")
    elif temperature <=30:
        print ("it is hot")
    elif temperature <=45:
        print ("it is really hot!")
    else:
        print ("it is boiling")

# %%
weather_commentary()
# Out:
# it is boiling

# %%
age = 17
has_id = True

if age >= 18 and has_id: 
    print ("you are welcome")
else: print ("get out of here")
# Out:
# get out of here
